# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

np.random.uniform(-90.000, 90.000, size=2000)

lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-90.000, 90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 720

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
   
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | svetlyy
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | mayumba
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | bubaque
# Processing Record 8 of Set 1 | mehamn
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | vila franca do campo
# Processing Record 11 of Set 1 | muleba
# Processing Record 12 of Set 1 | puerto colombia
# Processing Record 13 of Set 1 | inhuma
# Processing Record 14 of Set 1 | saint-francois
# Processing Record 15 of Set 1 | mulanje
# Processing Record 16 of Set 1 | port-gentil
# Processing Record 17 of Set 1 | monte alegre
# Processing Record 18 of Set 1 | lagoa
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 1 | gat
# Processing Record 22 of Set 1 | methoni
# Processing Record 23 of Set 1 | grand-santi
# Processing Record 24 of Set 1 | bardiyah
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | golden rock
# City not found. Skipping...
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | harrismith
# Processing Record 30 of Set 1 | beloha
# Processing Record 31 of Set 1 | gornopravdinsk
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | jalu
# Processing Record 35 of Set 1 | pangnirtung
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | matara
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | manjacaze
# Processing Record 40 of Set 1 | kleck
# City not found. Skipping...
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | lakhtar
# Processing Record 44 of Set 1 | khorixas
# Processing Record 45 of Set 1 | muli
# Processing Record 46 of Set 1 | ponta do sol
# Processing Record 47 of Set 1 | general roca
# Processing Record 48 of Set 1 | yelets
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | gamba
# Processing Record 1 of Set 2 | chicama
# Processing Record 2 of Set 2 | axim
# Processing Record 3 of Set 2 | morant bay
# Processing Record 4 of Set 2 | middlebury
# Processing Record 5 of Set 2 | kruisfontein
# Processing Record 6 of Set 2 | sechura
# Processing Record 7 of Set 2 | santa rosa
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | muros
# Processing Record 10 of Set 2 | ambilobe
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | karlovac
# Processing Record 13 of Set 2 | boca do acre
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | narsaq
# Processing Record 16 of Set 2 | puerto baquerizo moreno
# Processing Record 17 of Set 2 | atar
# Processing Record 18 of Set 2 | saint anthony
# Processing Record 19 of Set 2 | anloga
# Processing Record 20 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 2 | betanzos
# Processing Record 22 of Set 2 | progreso
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | virginia beach
# Processing Record 25 of Set 2 | valparaiso
# Processing Record 26 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 2 | itapuranga
# Processing Record 30 of Set 2 | saldanha
# Processing Record 31 of Set 2 | nouadhibou
# Processing Record 32 of Set 2 | taguatinga
# Processing Record 33 of Set 2 | salalah
# Processing Record 34 of Set 2 | sinnamary
# Processing Record 35 of Set 2 | nouakchott
# Processing Record 36 of Set 2 | sao joao da barra
# Processing Record 37 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | souillac
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | viytivka
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | mazagao
# Processing Record 45 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | sao filipe
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | turinskaya sloboda
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | cockburn town
# Processing Record 3 of Set 3 | chilca
# Processing Record 4 of Set 3 | luba
# Processing Record 5 of Set 3 | inhambane
# Processing Record 6 of Set 3 | rocha
# Processing Record 7 of Set 3 | gogrial
# Processing Record 8 of Set 3 | aras
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | camana
# Processing Record 11 of Set 3 | uxbridge
# Processing Record 12 of Set 3 | ewo
# Processing Record 13 of Set 3 | requena
# Processing Record 14 of Set 3 | boueni
# Processing Record 15 of Set 3 | esil
# Processing Record 16 of Set 3 | ovalle
# Processing Record 17 of Set 3 | bestobe
# Processing Record 18 of Set 3 | dahuk
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | vestmannaeyjar
# Processing Record 21 of Set 3 | vila velha
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | obo
# Processing Record 24 of Set 3 | palaia fokaia
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | sidi qasim
# City not found. Skipping...
# Processing Record 27 of Set 3 | nuuk
# Processing Record 28 of Set 3 | horki
# Processing Record 29 of Set 3 | porbandar
# Processing Record 30 of Set 3 | teguldet
# Processing Record 31 of Set 3 | foki
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | clyde river
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | sumbe
# Processing Record 36 of Set 3 | westport
# Processing Record 37 of Set 3 | batticaloa
# Processing Record 38 of Set 3 | calama
# Processing Record 39 of Set 3 | kalabo
# Processing Record 40 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 41 of Set 3 | selfoss
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | antsohihy
# Processing Record 44 of Set 3 | gaoual
# Processing Record 45 of Set 3 | uetze
# Processing Record 46 of Set 3 | cervo
# Processing Record 47 of Set 3 | batie
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | vardo
# Processing Record 50 of Set 3 | leshukonskoye
# Processing Record 1 of Set 4 | kudahuvadhoo
# Processing Record 2 of Set 4 | plyussa
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | sao felix do xingu
# Processing Record 5 of Set 4 | coquimbo
# Processing Record 6 of Set 4 | margate
# Processing Record 7 of Set 4 | olafsvik
# Processing Record 8 of Set 4 | iesolo
# Processing Record 9 of Set 4 | mindelo
# Processing Record 10 of Set 4 | sao jose da coroa grande
# Processing Record 11 of Set 4 | kirando
# Processing Record 12 of Set 4 | jutai
# Processing Record 13 of Set 4 | yanam
# Processing Record 14 of Set 4 | faya
# Processing Record 15 of Set 4 | grand gaube
# Processing Record 16 of Set 4 | kasane
# Processing Record 17 of Set 4 | vierzon
# Processing Record 18 of Set 4 | dergachi
# Processing Record 19 of Set 4 | nattam
# Processing Record 20 of Set 4 | pisco
# Processing Record 21 of Set 4 | santa maria
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | goderich
# Processing Record 24 of Set 4 | port elizabeth
# Processing Record 25 of Set 4 | saint-georges
# Processing Record 26 of Set 4 | khor
# Processing Record 27 of Set 4 | ati
# Processing Record 28 of Set 4 | monrovia
# Processing Record 29 of Set 4 | borba
# Processing Record 30 of Set 4 | bonthe
# Processing Record 31 of Set 4 | birnin kebbi
# Processing Record 32 of Set 4 | umm kaddadah
# Processing Record 33 of Set 4 | hanumangarh
# Processing Record 34 of Set 4 | mount pleasant
# Processing Record 35 of Set 4 | farkhor
# Processing Record 36 of Set 4 | itaituba
# Processing Record 37 of Set 4 | dhidhdhoo
# Processing Record 38 of Set 4 | bandarbeyla
# Processing Record 39 of Set 4 | ostrovnoy
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | rawson
# Processing Record 42 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 4 | katav-ivanovsk
# Processing Record 44 of Set 4 | weligama
# Processing Record 45 of Set 4 | clarence town
# Processing Record 46 of Set 4 | quatre cocos
# Processing Record 47 of Set 4 | tessalit
# Processing Record 48 of Set 4 | balkhash
# Processing Record 49 of Set 4 | spas-klepiki
# Processing Record 50 of Set 4 | paamiut
# Processing Record 1 of Set 5 | piranshahr
# Processing Record 2 of Set 5 | sapucaia
# Processing Record 3 of Set 5 | kamenka
# Processing Record 4 of Set 5 | budaun
# Processing Record 5 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 5 | rosetta
# Processing Record 7 of Set 5 | pemba
# Processing Record 8 of Set 5 | abha
# Processing Record 9 of Set 5 | caconda
# Processing Record 10 of Set 5 | kishanganj
# Processing Record 11 of Set 5 | necochea
# Processing Record 12 of Set 5 | oblivskaya
# Processing Record 13 of Set 5 | rio grande
# Processing Record 14 of Set 5 | damaturu
# Processing Record 15 of Set 5 | barcelos
# Processing Record 16 of Set 5 | hobyo
# Processing Record 17 of Set 5 | comodoro rivadavia
# Processing Record 18 of Set 5 | kumla
# Processing Record 19 of Set 5 | ribas do rio pardo
# Processing Record 20 of Set 5 | gusau
# Processing Record 21 of Set 5 | kusk
# City not found. Skipping...
# Processing Record 22 of Set 5 | staraya poltavka
# Processing Record 23 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 5 | satka
# Processing Record 25 of Set 5 | marawi
# Processing Record 26 of Set 5 | dingle
# Processing Record 27 of Set 5 | thurso
# Processing Record 28 of Set 5 | lasa
# Processing Record 29 of Set 5 | honningsvag
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | agadez
# Processing Record 32 of Set 5 | ugoofaaru
# Processing Record 33 of Set 5 | husavik
# Processing Record 34 of Set 5 | kemijarvi
# Processing Record 35 of Set 5 | kissidougou
# Processing Record 36 of Set 5 | pavlodolskaya
# Processing Record 37 of Set 5 | hofn
# Processing Record 38 of Set 5 | ocland
# Processing Record 39 of Set 5 | codrington
# Processing Record 40 of Set 5 | mahebourg
# Processing Record 41 of Set 5 | cap malheureux
# Processing Record 42 of Set 5 | igarka
# Processing Record 43 of Set 5 | harper
# Processing Record 44 of Set 5 | miraflores
# Processing Record 45 of Set 5 | geraldton
# Processing Record 46 of Set 5 | micheweni
# Processing Record 47 of Set 5 | impfondo
# Processing Record 48 of Set 5 | pamplona
# Processing Record 49 of Set 5 | esperantina
# Processing Record 50 of Set 5 | jepelacio
# Processing Record 1 of Set 6 | duz
# City not found. Skipping...
# Processing Record 2 of Set 6 | lucapa
# Processing Record 3 of Set 6 | aksay
# Processing Record 4 of Set 6 | ereymentau
# Processing Record 5 of Set 6 | salinas
# Processing Record 6 of Set 6 | walvis bay
# Processing Record 7 of Set 6 | umtata
# Processing Record 8 of Set 6 | islamkot
# Processing Record 9 of Set 6 | colwyn bay
# Processing Record 10 of Set 6 | baft
# Processing Record 11 of Set 6 | bumba
# Processing Record 12 of Set 6 | hunucma
# Processing Record 13 of Set 6 | muisne
# Processing Record 14 of Set 6 | arkalokhorion
# City not found. Skipping...
# Processing Record 15 of Set 6 | willowmore
# Processing Record 16 of Set 6 | santa ana
# Processing Record 17 of Set 6 | ayagoz
# Processing Record 18 of Set 6 | verkhnyaya toyma
# Processing Record 19 of Set 6 | thinadhoo
# Processing Record 20 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 6 | mitsamiouli
# Processing Record 22 of Set 6 | krasnoselkup
# Processing Record 23 of Set 6 | opuwo
# Processing Record 24 of Set 6 | viedma
# Processing Record 25 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | nsanje
# Processing Record 27 of Set 6 | menongue
# Processing Record 28 of Set 6 | kumluca
# Processing Record 29 of Set 6 | diego de almagro
# Processing Record 30 of Set 6 | marfino
# Processing Record 31 of Set 6 | carutapera
# Processing Record 32 of Set 6 | tazovskiy
# Processing Record 33 of Set 6 | ust-tsilma
# Processing Record 34 of Set 6 | sorland
# Processing Record 35 of Set 6 | richards bay
# Processing Record 36 of Set 6 | tira sujanpur
# Processing Record 37 of Set 6 | skjervoy
# Processing Record 38 of Set 6 | alta floresta
# Processing Record 39 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 6 | mafinga
# Processing Record 41 of Set 6 | kalmanka
# Processing Record 42 of Set 6 | panjab
# Processing Record 43 of Set 6 | touros
# Processing Record 44 of Set 6 | dumka
# Processing Record 45 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 46 of Set 6 | cabedelo
# Processing Record 47 of Set 6 | volkhov
# Processing Record 48 of Set 6 | mbandaka
# Processing Record 49 of Set 6 | nador
# Processing Record 50 of Set 6 | havoysund
# Processing Record 1 of Set 7 | klaksvik
# Processing Record 2 of Set 7 | peine
# Processing Record 3 of Set 7 | monastyrshchina
# Processing Record 4 of Set 7 | chapayevka
# Processing Record 5 of Set 7 | puerto madryn
# Processing Record 6 of Set 7 | veraval
# Processing Record 7 of Set 7 | tripoli
# Processing Record 8 of Set 7 | carnarvon
# Processing Record 9 of Set 7 | ayios matthaios
# City not found. Skipping...
# Processing Record 10 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 7 | kirkuk
# Processing Record 12 of Set 7 | imbituba
# Processing Record 13 of Set 7 | mancio lima
# Processing Record 14 of Set 7 | troitsko-pechorsk
# Processing Record 15 of Set 7 | fereydun kenar
# Processing Record 16 of Set 7 | wielun
# Processing Record 17 of Set 7 | cayenne
# Processing Record 18 of Set 7 | hargeysa
# Processing Record 19 of Set 7 | andenes
# Processing Record 20 of Set 7 | carahue
# Processing Record 21 of Set 7 | padang
# Processing Record 22 of Set 7 | sitrah
# Processing Record 23 of Set 7 | paita
# Processing Record 24 of Set 7 | porto seguro
# Processing Record 25 of Set 7 | guantanamo
# Processing Record 26 of Set 7 | itarema
# Processing Record 27 of Set 7 | tsiroanomandidy
# Processing Record 28 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 29 of Set 7 | sambava
# Processing Record 30 of Set 7 | marinette
# Processing Record 31 of Set 7 | thunder bay
# Processing Record 32 of Set 7 | castro
# Processing Record 33 of Set 7 | gbarnga
# Processing Record 34 of Set 7 | tsabong
# Processing Record 35 of Set 7 | salinopolis
# Processing Record 36 of Set 7 | yar-sale
# Processing Record 37 of Set 7 | ancud
# Processing Record 38 of Set 7 | kuytun
# Processing Record 39 of Set 7 | kajaani
# Processing Record 40 of Set 7 | yellandu
# Processing Record 41 of Set 7 | bergen
# Processing Record 42 of Set 7 | santa elena
# Processing Record 43 of Set 7 | brae
# Processing Record 44 of Set 7 | kinsale
# Processing Record 45 of Set 7 | naregal
# Processing Record 46 of Set 7 | puerto narino
# Processing Record 47 of Set 7 | rioja
# Processing Record 48 of Set 7 | santa lucia
# Processing Record 49 of Set 7 | agustin codazzi
# Processing Record 50 of Set 7 | zabol
# Processing Record 1 of Set 8 | saint-augustin
# Processing Record 2 of Set 8 | manzil jamil
# City not found. Skipping...
# Processing Record 3 of Set 8 | marsh harbour
# Processing Record 4 of Set 8 | himora
# City not found. Skipping...
# Processing Record 5 of Set 8 | guasdualito
# Processing Record 6 of Set 8 | saint-pierre
# Processing Record 7 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 8 | rio gallegos
# Processing Record 9 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 8 | tesalia
# Processing Record 11 of Set 8 | marzuq
# Processing Record 12 of Set 8 | kefalovrison
# City not found. Skipping...
# Processing Record 13 of Set 8 | kayes
# Processing Record 14 of Set 8 | glarus
# Processing Record 15 of Set 8 | verkhnyaya inta
# Processing Record 16 of Set 8 | jaypur
# Processing Record 17 of Set 8 | kavakli
# Processing Record 18 of Set 8 | aksu
# Processing Record 19 of Set 8 | le mans
# Processing Record 20 of Set 8 | fort-shevchenko
# Processing Record 21 of Set 8 | berlevag
# Processing Record 22 of Set 8 | mpika
# Processing Record 23 of Set 8 | plouzane
# Processing Record 24 of Set 8 | camabatela
# Processing Record 25 of Set 8 | manta
# Processing Record 26 of Set 8 | akcaabat
# Processing Record 27 of Set 8 | iskateley
# Processing Record 28 of Set 8 | temir
# Processing Record 29 of Set 8 | altea
# Processing Record 30 of Set 8 | tamandare
# Processing Record 31 of Set 8 | lyskovo
# Processing Record 32 of Set 8 | gualaquiza
# Processing Record 33 of Set 8 | puerto carreno
# Processing Record 34 of Set 8 | shrewsbury
# Processing Record 35 of Set 8 | vallenar
# Processing Record 36 of Set 8 | barmer
# Processing Record 37 of Set 8 | panaba
# Processing Record 38 of Set 8 | george town
# Processing Record 39 of Set 8 | durazno
# Processing Record 40 of Set 8 | verkhniy baskunchak
# Processing Record 41 of Set 8 | mizdah
# Processing Record 42 of Set 8 | telimele
# Processing Record 43 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 8 | sarai
# Processing Record 45 of Set 8 | luebo
# Processing Record 46 of Set 8 | tabou
# Processing Record 47 of Set 8 | energetik
# Processing Record 48 of Set 8 | constitucion
# Processing Record 49 of Set 8 | tortoli
# Processing Record 50 of Set 8 | cape coast
# Processing Record 1 of Set 9 | satara
# Processing Record 2 of Set 9 | camocim
# Processing Record 3 of Set 9 | mao
# Processing Record 4 of Set 9 | irgakly
# Processing Record 5 of Set 9 | henties bay
# Processing Record 6 of Set 9 | coihaique
# Processing Record 7 of Set 9 | riviere-au-renard
# Processing Record 8 of Set 9 | pestovo
# Processing Record 9 of Set 9 | bilma
# Processing Record 10 of Set 9 | chingirlau
# Processing Record 11 of Set 9 | liapades
# City not found. Skipping...
# Processing Record 12 of Set 9 | zatoka
# Processing Record 13 of Set 9 | bayan
# Processing Record 14 of Set 9 | timizart
# Processing Record 15 of Set 9 | banda aceh
# Processing Record 16 of Set 9 | balykshi
# Processing Record 17 of Set 9 | izhma
# Processing Record 18 of Set 9 | ustka
# Processing Record 19 of Set 9 | emborion
# Processing Record 20 of Set 9 | charlestown
# Processing Record 21 of Set 9 | nantucket
# Processing Record 22 of Set 9 | moose factory
# Processing Record 23 of Set 9 | balta
# Processing Record 24 of Set 9 | dundalk
# Processing Record 25 of Set 9 | port shepstone
# Processing Record 26 of Set 9 | kabo
# Processing Record 27 of Set 9 | tucupita
# Processing Record 28 of Set 9 | narasannapeta
# Processing Record 29 of Set 9 | tambacounda
# Processing Record 30 of Set 9 | dioknisi
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | vestmanna
# Processing Record 33 of Set 9 | urumqi
# Processing Record 34 of Set 9 | omboue
# Processing Record 35 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 36 of Set 9 | kibala
# Processing Record 37 of Set 9 | west bay
# Processing Record 38 of Set 9 | namibe
# Processing Record 39 of Set 9 | ylivieska
# Processing Record 40 of Set 9 | vilcun
# Processing Record 41 of Set 9 | sogne
# Processing Record 42 of Set 9 | conceicao do araguaia
# Processing Record 43 of Set 9 | kholmogory
# Processing Record 44 of Set 9 | cap-aux-meules
# Processing Record 45 of Set 9 | pushkino
# Processing Record 46 of Set 9 | bandipur
# Processing Record 47 of Set 9 | chalus
# Processing Record 48 of Set 9 | madimba
# Processing Record 49 of Set 9 | itacarambi
# Processing Record 50 of Set 9 | sfantu gheorghe
# Processing Record 1 of Set 10 | conceicao da barra
# Processing Record 2 of Set 10 | shpykiv
# City not found. Skipping...
# Processing Record 3 of Set 10 | lerwick
# Processing Record 4 of Set 10 | minab
# Processing Record 5 of Set 10 | luanda
# Processing Record 6 of Set 10 | aykino
# Processing Record 7 of Set 10 | strezhevoy
# Processing Record 8 of Set 10 | porto novo
# Processing Record 9 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 10 | voiste
# City not found. Skipping...
# Processing Record 11 of Set 10 | korla
# Processing Record 12 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 10 | afrikanda
# Processing Record 14 of Set 10 | sioux lookout
# Processing Record 15 of Set 10 | balkanabat
# Processing Record 16 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 17 of Set 10 | cururupu
# Processing Record 18 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 19 of Set 10 | merrill
# Processing Record 20 of Set 10 | nebolchi
# Processing Record 21 of Set 10 | lima
# Processing Record 22 of Set 10 | etaples
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | pizarro
# Processing Record 25 of Set 10 | rabo de peixe
# Processing Record 26 of Set 10 | afyonkarahisar
# Processing Record 27 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 10 | talnakh
# Processing Record 29 of Set 10 | djibo
# Processing Record 30 of Set 10 | tchibanga
# Processing Record 31 of Set 10 | qaqortoq
# Processing Record 32 of Set 10 | anori
# Processing Record 33 of Set 10 | kattivakkam
# Processing Record 34 of Set 10 | rio cuarto
# Processing Record 35 of Set 10 | havre-saint-pierre
# Processing Record 36 of Set 10 | masuguru
# Processing Record 37 of Set 10 | maxixe
# Processing Record 38 of Set 10 | sapele
# Processing Record 39 of Set 10 | chhoti sadri
# Processing Record 40 of Set 10 | pesaro
# Processing Record 41 of Set 10 | tsumeb
# Processing Record 42 of Set 10 | kalmunai
# Processing Record 43 of Set 10 | revda
# Processing Record 44 of Set 10 | araria
# Processing Record 45 of Set 10 | amantea
# Processing Record 46 of Set 10 | chaplynka
# Processing Record 47 of Set 10 | strathaven
# Processing Record 48 of Set 10 | uran
# Processing Record 49 of Set 10 | uige
# Processing Record 50 of Set 10 | soyo
# Processing Record 1 of Set 11 | llano de piedra
# Processing Record 2 of Set 11 | puerto cabello
# Processing Record 3 of Set 11 | key west
# Processing Record 4 of Set 11 | digby
# Processing Record 5 of Set 11 | busayra
# Processing Record 6 of Set 11 | marechal floriano
# Processing Record 7 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 11 | fenoarivo
# Processing Record 9 of Set 11 | kabare
# Processing Record 10 of Set 11 | sisimiut
# Processing Record 11 of Set 11 | mogadishu
# Processing Record 12 of Set 11 | bereda
# Processing Record 13 of Set 11 | halifax
# Processing Record 14 of Set 11 | qena
# Processing Record 15 of Set 11 | reconquista
# Processing Record 16 of Set 11 | abu dhabi
# Processing Record 17 of Set 11 | oktyabrskiy
# Processing Record 18 of Set 11 | kjollefjord
# Processing Record 19 of Set 11 | mecca
# Processing Record 20 of Set 11 | cacapava do sul
# Processing Record 21 of Set 11 | erandique
# Processing Record 22 of Set 11 | naryan-mar
# Processing Record 23 of Set 11 | serenje
# Processing Record 24 of Set 11 | zhanakorgan
# Processing Record 25 of Set 11 | hashtrud
# Processing Record 26 of Set 11 | mgandu
# Processing Record 27 of Set 11 | tarpon springs
# Processing Record 28 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 29 of Set 11 | iralaya
# Processing Record 30 of Set 11 | panyutyne
# Processing Record 31 of Set 11 | lodja
# Processing Record 32 of Set 11 | cottbus
# Processing Record 33 of Set 11 | kidal
# Processing Record 34 of Set 11 | port blair
# Processing Record 35 of Set 11 | novomalorossiyskaya
# Processing Record 36 of Set 11 | juazeiro
# Processing Record 37 of Set 11 | florida
# Processing Record 38 of Set 11 | sidi ali
# Processing Record 39 of Set 11 | raudeberg
# Processing Record 40 of Set 11 | araioses
# Processing Record 41 of Set 11 | port said
# Processing Record 42 of Set 11 | timbiqui
# Processing Record 43 of Set 11 | bantry
# Processing Record 44 of Set 11 | saint-leu
# Processing Record 45 of Set 11 | maddur
# Processing Record 46 of Set 11 | sorokino
# Processing Record 47 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 11 | nikolayevka
# Processing Record 49 of Set 11 | bonavista
# Processing Record 50 of Set 11 | filingue
# Processing Record 1 of Set 12 | sur
# Processing Record 2 of Set 12 | ustye
# Processing Record 3 of Set 12 | natal
# Processing Record 4 of Set 12 | binga
# Processing Record 5 of Set 12 | la asuncion
# Processing Record 6 of Set 12 | serik
# Processing Record 7 of Set 12 | sao miguel do araguaia
# Processing Record 8 of Set 12 | areosa
# Processing Record 9 of Set 12 | krasnyy oktyabr
# Processing Record 10 of Set 12 | ulu-telyak
# Processing Record 11 of Set 12 | novosemeykino
# Processing Record 12 of Set 12 | guarapari
# Processing Record 13 of Set 12 | buraydah
# Processing Record 14 of Set 12 | polovinnoye
# Processing Record 15 of Set 12 | gazojak
# Processing Record 16 of Set 12 | coshocton
# Processing Record 17 of Set 12 | susangerd
# Processing Record 18 of Set 12 | chimore
# Processing Record 19 of Set 12 | policoro
# Processing Record 20 of Set 12 | amarante do maranhao
# Processing Record 21 of Set 12 | lovozero
# Processing Record 22 of Set 12 | dwarka
# Processing Record 23 of Set 12 | lazurne
# Processing Record 24 of Set 12 | glyadyanskoye
# Processing Record 25 of Set 12 | bay roberts
# Processing Record 26 of Set 12 | marystown
# Processing Record 27 of Set 12 | ayabaca
# Processing Record 28 of Set 12 | sistranda
# Processing Record 29 of Set 12 | dudinka
# Processing Record 30 of Set 12 | ellisras
# Processing Record 31 of Set 12 | barghat
# Processing Record 32 of Set 12 | andros town
# Processing Record 33 of Set 12 | aswan
# Processing Record 34 of Set 12 | sesvete
# Processing Record 35 of Set 12 | brumado
# Processing Record 36 of Set 12 | grindavik
# Processing Record 37 of Set 12 | veshenskaya
# Processing Record 38 of Set 12 | tutoia
# Processing Record 39 of Set 12 | talmenka
# Processing Record 40 of Set 12 | zhezkazgan
# Processing Record 41 of Set 12 | mallaig
# Processing Record 42 of Set 12 | aksarka
# Processing Record 43 of Set 12 | iquique
# Processing Record 44 of Set 12 | praia da vitoria
# Processing Record 45 of Set 12 | garowe
# Processing Record 46 of Set 12 | ituiutaba
# Processing Record 47 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 48 of Set 12 | zaraza
# Processing Record 49 of Set 12 | mocuba
# Processing Record 50 of Set 12 | ashqelon
# Processing Record 1 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 2 of Set 13 | mende
# Processing Record 3 of Set 13 | dubna
# Processing Record 4 of Set 13 | sakakah
# Processing Record 5 of Set 13 | tarauaca
# Processing Record 6 of Set 13 | kismayo
# Processing Record 7 of Set 13 | tucuma
# Processing Record 8 of Set 13 | teguise
# Processing Record 9 of Set 13 | inirida
# Processing Record 10 of Set 13 | arlit
# Processing Record 11 of Set 13 | vilnius
# Processing Record 12 of Set 13 | yarega
# Processing Record 13 of Set 13 | camacha
# Processing Record 14 of Set 13 | la primavera
# Processing Record 15 of Set 13 | anzio
# Processing Record 16 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 17 of Set 13 | sokolka
# Processing Record 18 of Set 13 | alanya
# Processing Record 19 of Set 13 | conakry
# Processing Record 20 of Set 13 | moen
# Processing Record 21 of Set 13 | bhuj
# Processing Record 22 of Set 13 | moussoro
# Processing Record 23 of Set 13 | linares
# Processing Record 24 of Set 13 | kanadey
# Processing Record 25 of Set 13 | san rafael
# Processing Record 26 of Set 13 | sehithwa
# Processing Record 27 of Set 13 | meiganga
# Processing Record 28 of Set 13 | rathdrum
# Processing Record 29 of Set 13 | igrim
# Processing Record 30 of Set 13 | emba
# Processing Record 31 of Set 13 | alfred
# Processing Record 32 of Set 13 | povrly
# Processing Record 33 of Set 13 | guatire
# Processing Record 34 of Set 13 | hammerfest
# Processing Record 35 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 13 | merritt island
# Processing Record 37 of Set 13 | edgewater
# Processing Record 38 of Set 13 | zile
# Processing Record 39 of Set 13 | kiskunfelegyhaza
# Processing Record 40 of Set 13 | hualmay
# Processing Record 41 of Set 13 | storforshei
# Processing Record 42 of Set 13 | waddan
# Processing Record 43 of Set 13 | awjilah
# Processing Record 44 of Set 13 | seminole
# Processing Record 45 of Set 13 | oleksandrivka
# Processing Record 46 of Set 13 | taltal
# Processing Record 47 of Set 13 | gari
# Processing Record 48 of Set 13 | staryy nadym
# Processing Record 49 of Set 13 | malatya
# Processing Record 50 of Set 13 | eyl
# Processing Record 1 of Set 14 | hambantota
# Processing Record 2 of Set 14 | pavilosta
# Processing Record 3 of Set 14 | la massana
# Processing Record 4 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 5 of Set 14 | vila do maio
# Processing Record 6 of Set 14 | oussouye
# Processing Record 7 of Set 14 | kiruna
# Processing Record 8 of Set 14 | dinan
# Processing Record 9 of Set 14 | khash
# Processing Record 10 of Set 14 | pimenta bueno
# Processing Record 11 of Set 14 | carupano
# Processing Record 12 of Set 14 | vitoria da conquista
# Processing Record 13 of Set 14 | umba
# Processing Record 14 of Set 14 | lulea
# Processing Record 15 of Set 14 | piacabucu
# Processing Record 16 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 14 | puerto del rosario
# Processing Record 18 of Set 14 | boulsa
# Processing Record 19 of Set 14 | marau
# Processing Record 20 of Set 14 | carauari
# Processing Record 21 of Set 14 | plerin
# Processing Record 22 of Set 14 | jaguey grande
# Processing Record 23 of Set 14 | pedernales
# Processing Record 24 of Set 14 | oranjemund
# Processing Record 25 of Set 14 | marrakesh
# Processing Record 26 of Set 14 | golfito
# Processing Record 27 of Set 14 | pontes e lacerda
# Processing Record 28 of Set 14 | birjand
# Processing Record 29 of Set 14 | wajir
# Processing Record 30 of Set 14 | pocosol
# Processing Record 31 of Set 14 | pirgos
# Processing Record 32 of Set 14 | dawlatabad
# Processing Record 33 of Set 14 | la palma
# Processing Record 34 of Set 14 | kavaratti
# Processing Record 35 of Set 14 | lardos
# Processing Record 36 of Set 14 | chutove
# Processing Record 37 of Set 14 | colombia
# Processing Record 38 of Set 14 | van
# Processing Record 39 of Set 14 | correia pinto
# Processing Record 40 of Set 14 | san andres
# Processing Record 41 of Set 14 | sarany
# Processing Record 42 of Set 14 | urdoma
# Processing Record 43 of Set 14 | umuahia
# Processing Record 44 of Set 14 | eregli
# Processing Record 45 of Set 14 | kostroma
# Processing Record 46 of Set 14 | aleksandrov gay
# Processing Record 47 of Set 14 | wattegama
# Processing Record 48 of Set 14 | manohar thana
# Processing Record 49 of Set 14 | boende
# Processing Record 50 of Set 14 | cocobeach
# Processing Record 1 of Set 15 | clinton
# Processing Record 2 of Set 15 | sault sainte marie
# Processing Record 3 of Set 15 | olinda
# Processing Record 4 of Set 15 | doha
# Processing Record 5 of Set 15 | mangrol
# Processing Record 6 of Set 15 | oriximina
# Processing Record 7 of Set 15 | bad wildbad
# Processing Record 8 of Set 15 | mapiripan
# Processing Record 9 of Set 15 | diamantina
# Processing Record 10 of Set 15 | yining
# Processing Record 11 of Set 15 | hendrina
# Processing Record 12 of Set 15 | lebyazhye
# Processing Record 13 of Set 15 | panguipulli
# Processing Record 14 of Set 15 | caraballeda
# Processing Record 15 of Set 15 | baffa
# Processing Record 16 of Set 15 | quelimane
# Processing Record 17 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 15 | foso
# Processing Record 19 of Set 15 | toamasina
# Processing Record 20 of Set 15 | tornio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 667

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0               Svetlyy  54.6750  20.1347     37.96        71          94
# 1               Ushuaia -54.8000 -68.3000     47.86        61          75
# 2         Mar Del Plata -38.0023 -57.5575     61.09        72           0
# 3               Mayumba  -3.4320  10.6554     75.63        83          99
# 4             Bathsheba  13.2167 -59.5167     81.21        78          40
# 5                  Chuy -33.6971 -53.4616     54.82        66           0
# 6               Bubaque  11.2833 -15.8333     81.86        72         100
# 7                Mehamn  71.0357  27.8492     40.95        75          75
# 8            Bredasdorp -34.5322  20.0403     62.46        66          93
# 9  Vila Franca Do Campo  37.7167 -25.4333     67.19        90          59
#
#    Wind Speed Country                 Date
# 0       16.20      RU  2022-11-16 04:58:17
# 1       17.27      AR  2022-11-16 04:55:57
# 2        4.61      AR  2022-11-16 04:58:18
# 3        6.58      GA  2022-11-16 04:58:18
# 4       17.27      BB  2022-11-16 04:58:18
# 5        6.24      UY  2022-11-16 04:58:19
# 6        8.32      GW  2022-11-16 04:58:19
# 7       13.80      NO  2022-11-16 04:58:20
# 8        4.50      ZA  2022-11-16 04:58:20
# 9       15.66      PT  2022-11-16 04:58:21

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          Svetlyy      RU  54.6750  20.1347     37.96        71          94
# 1          Ushuaia      AR -54.8000 -68.3000     47.86        61          75
# 2    Mar Del Plata      AR -38.0023 -57.5575     61.09        72           0
# 3          Mayumba      GA  -3.4320  10.6554     75.63        83          99
# 4        Bathsheba      BB  13.2167 -59.5167     81.21        78          40
# ..             ...     ...      ...      ...       ...       ...         ...
# 662          Baffa      PK  34.4378  73.2194     61.18        35          27
# 663      Quelimane      MZ -17.8786  36.8883     80.80        69           3
# 664           Foso      GH   5.7012  -1.2866     71.46        98          28
# 665      Toamasina      MG -18.1667  49.3833     75.29        80          75
# 666         Tornio      FI  65.8481  24.1466     15.82        78          98
#
#      Wind Speed Country
# 0         16.20      RU
# 1         17.27      AR
# 2          4.61      AR
# 3          6.58      GA
# 4         17.27      BB
# ..          ...     ...
# 662        2.08      PK
# 663        3.80      MZ
# 664        2.10      GH
# 665        6.08      MG
# 666        4.90      FI
#
# [667 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Data/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
